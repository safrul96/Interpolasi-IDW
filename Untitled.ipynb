# %%
import numpy as py
import pandas as pd

# %%
data = pd.read_excel('cuaca_geom.xlsx')
data
# Out:
#         id  idGeom  temperatur  curahHujan  lamaPenyin  radiasiPen  \
# 0        1       1        73.6        3.06         NaN         NaN
# 1       16       2        73.6        3.06         NaN         NaN
# 2       31       3        73.6        3.06         NaN         NaN
# 3       46       4        68.9        4.41         NaN         NaN
# 4       61       5        73.6        3.06         NaN         NaN
# ...    ...     ...         ...         ...         ...         ...
# 2375  2320      24        71.5        0.53         NaN       226.5
# 2376  2335      25        71.9        0.47         NaN       240.1
# 2377  2350      26        71.9        0.47         NaN       240.1
# 2378  2365      27        71.5        0.53         NaN       226.5
# 2379  2380      28        72.0        0.32         NaN       229.6
#
#                       tanggal kabupaten/   spt
# 0     2022/04/19 00:00:00.000   MAGELANG     1
# 1     2022/04/19 00:00:00.000   MAGELANG     2
# ...

# %%
data.head
# Out:
# <bound method NDFrame.head of         id  idGeom  temperatur  curahHujan  lamaPenyin  radiasiPen  \
# 0        1       1        73.6        3.06         NaN         NaN
# 1       16       2        73.6        3.06         NaN         NaN
# 2       31       3        73.6        3.06         NaN         NaN
# 3       46       4        68.9        4.41         NaN         NaN
# 4       61       5        73.6        3.06         NaN         NaN
# ...    ...     ...         ...         ...         ...         ...
# 2375  2320      24        71.5        0.53         NaN       226.5
# 2376  2335      25        71.9        0.47         NaN       240.1
# 2377  2350      26        71.9        0.47         NaN       240.1
# 2378  2365      27        71.5        0.53         NaN       226.5
# 2379  2380      28        72.0        0.32         NaN       229.6
#
#                       tanggal kabupaten/   spt
# 0     2022/04/19 00:00:00.000   MAGELANG     1
# ...

# %%
data.sort_values(by =["radiasiPen","tanggal"])[["radiasiPen","tanggal"]]
# Out:
#       radiasiPen                  tanggal
# 1491        11.3  2022/07/16 00:00:00.000
# 1492        11.3  2022/07/16 00:00:00.000
# 1496        11.3  2022/07/16 00:00:00.000
# 1498        11.3  2022/07/16 00:00:00.000
# 1501        11.3  2022/07/16 00:00:00.000
# ...          ...                      ...
# 667          NaN  2022/05/22 00:00:00.000
# 668          NaN  2022/05/22 00:00:00.000
# 669          NaN  2022/05/22 00:00:00.000
# 670          NaN  2022/05/22 00:00:00.000
# 671          NaN  2022/05/22 00:00:00.000
#
# [2380 rows x 2 columns]
